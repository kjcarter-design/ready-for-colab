# %%
import os

# %%
lab_dir = './lab_dir'
os.path.exists(lab_dir)
# Out:
# False

# %%
os.mkdir(lab_dir)

# %%
os.listdir(lab_dir)
# Out:
# []

# %%
dir (os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'error',
#  'execl',
#  'execle',
#  'execlp',
#  'execlpe',
#  'execv',
#  'execve',
#  'execvp',
#  'execvpe',
#  'extsep',
#  'fdopen',
#  'fsdecode',
#  'fsencode',
#  'fspath',
#  'fstat',
#  'fsync',
#  'ftruncate',
#  'get_exec_path',
#  'get_handle_inheritable',
#  'get_inheritable',
#  'get_terminal_size',
#  'getcwd',
#  'getcwdb',
#  'getenv',
#  'getlogin',
#  'getpid',
#  'getppid',
#  'isatty',
#  'kill',
#  'linesep',
#  'link',
#  'listdir',
#  'lseek',
#  'lstat',
#  'makedirs',
#  'mkdir',
#  'name',
#  'open',
#  'pardir',
#  'path',
#  'pathsep',
#  'pipe',
#  'popen',
#  'putenv',
#  'read',
#  'readlink',
#  'remove',
#  'removedirs',
#  'rename',
#  'renames',
#  'replace',
#  'rmdir',
#  'scandir',
#  'sep',
#  'set_handle_inheritable',
#  'set_inheritable',
#  'spawnl',
#  'spawnle',
#  'spawnv',
#  'spawnve',
#  'st',
#  'startfile',
#  'stat',
#  'stat_result',
#  'statvfs_result',
#  'strerror',
#  'supports_bytes_environ',
#  'supports_dir_fd',
#  'supports_effective_ids',
#  'supports_fd',
#  'supports_follow_symlinks',
#  'symlink',
#  'sys',
#  'system',
#  'terminal_size',
#  'times',
#  'times_result',
#  'truncate',
#  'umask',
#  'uname_result',
#  'unlink',
#  'urandom',
#  'utime',
#  'waitpid',
#  'walk',
#  'write']

# %%
file_name = 'os_dir.txt'
full_file_name = os.path.join(lab_dir, file_name); full_file_name
# Out:
# './lab_dir\\os_dir.txt'

# %%
with open (full_file_name, 'w') as fout:
    for idx, e in enumerate(dir(os)):
        fout.write (f'{idx}:{e}\n')

# %%
file_lines = []
with open (full_file_name, 'r') as fin:
    for line in fin:
        file_lines.append(line)

file_lines
# Out:
# ['0:DirEntry\n',
#  '1:F_OK\n',
#  '2:MutableMapping\n',
#  '3:O_APPEND\n',
#  '4:O_BINARY\n',
#  '5:O_CREAT\n',
#  '6:O_EXCL\n',
#  '7:O_NOINHERIT\n',
#  '8:O_RANDOM\n',
#  '9:O_RDONLY\n',
#  '10:O_RDWR\n',
#  '11:O_SEQUENTIAL\n',
#  '12:O_SHORT_LIVED\n',
#  '13:O_TEMPORARY\n',
#  '14:O_TEXT\n',
#  '15:O_TRUNC\n',
#  '16:O_WRONLY\n',
#  '17:P_DETACH\n',
#  '18:P_NOWAIT\n',
#  '19:P_NOWAITO\n',
#  '20:P_OVERLAY\n',
#  '21:P_WAIT\n',
#  '22:PathLike\n',
#  '23:R_OK\n',
#  '24:SEEK_CUR\n',
#  '25:SEEK_END\n',
#  '26:SEEK_SET\n',
#  '27:TMP_MAX\n',
#  '28:W_OK\n',
#  '29:X_OK\n',
#  '30:_Environ\n',
#  '31:__all__\n',
#  '32:__builtins__\n',
#  '33:__cached__\n',
#  '34:__doc__\n',
#  '35:__file__\n',
#  '36:__loader__\n',
#  '37:__name__\n',
#  '38:__package__\n',
#  '39:__spec__\n',
#  '40:_execvpe\n',
#  '41:_exists\n',
#  '42:_exit\n',
#  '43:_fspath\n',
#  '44:_get_exports_list\n',
#  '45:_putenv\n',
#  '46:_unsetenv\n',
#  '47:_wrap_close\n',
#  '48:abc\n',
#  '49:abort\n',
#  '50:access\n',
#  '51:altsep\n',
#  '52:chdir\n',
#  '53:chmod\n',
#  '54:close\n',
#  '55:closerange\n',
#  '56:cpu_count\n',
#  '57:curdir\n',
#  '58:defpath\n',
#  '59:device_encoding\n',
#  '60:devnull\n',
#  '61:dup\n',
#  '62:dup2\n',
#  '63:environ\n',
#  '64:error\n',
#  '65:execl\n',
#  '66:execle\n',
#  '67:execlp\n',
#  '68:execlpe\n',
#  '69:execv\n',
#  '70:execve\n',
#  '71:execvp\n',
#  '72:execvpe\n',
#  '73:extsep\n',
#  '74:fdopen\n',
#  '75:fsdecode\n',
#  '76:fsencode\n',
#  '77:fspath\n',
#  '78:fstat\n',
#  '79:fsync\n',
#  '80:ftruncate\n',
#  '81:get_exec_path\n',
#  '82:get_handle_inheritable\n',
#  '83:get_inheritable\n',
#  '84:get_terminal_size\n',
#  '85:getcwd\n',
#  '86:getcwdb\n',
#  '87:getenv\n',
#  '88:getlogin\n',
#  '89:getpid\n',
#  '90:getppid\n',
#  '91:isatty\n',
#  '92:kill\n',
#  '93:linesep\n',
#  '94:link\n',
#  '95:listdir\n',
#  '96:lseek\n',
#  '97:lstat\n',
#  '98:makedirs\n',
#  '99:mkdir\n',
#  '100:name\n',
#  '101:open\n',
#  '102:pardir\n',
#  '103:path\n',
#  '104:pathsep\n',
#  '105:pipe\n',
#  '106:popen\n',
#  '107:putenv\n',
#  '108:read\n',
#  '109:readlink\n',
#  '110:remove\n',
#  '111:removedirs\n',
#  '112:rename\n',
#  '113:renames\n',
#  '114:replace\n',
#  '115:rmdir\n',
#  '116:scandir\n',
#  '117:sep\n',
#  '118:set_handle_inheritable\n',
#  '119:set_inheritable\n',
#  '120:spawnl\n',
#  '121:spawnle\n',
#  '122:spawnv\n',
#  '123:spawnve\n',
#  '124:st\n',
#  '125:startfile\n',
#  '126:stat\n',
#  '127:stat_result\n',
#  '128:statvfs_result\n',
#  '129:strerror\n',
#  '130:supports_bytes_environ\n',
#  '131:supports_dir_fd\n',
#  '132:supports_effective_ids\n',
#  '133:supports_fd\n',
#  '134:supports_follow_symlinks\n',
#  '135:symlink\n',
#  '136:sys\n',
#  '137:system\n',
#  '138:terminal_size\n',
#  '139:times\n',
#  '140:times_result\n',
#  '141:truncate\n',
#  '142:umask\n',
#  '143:uname_result\n',
#  '144:unlink\n',
#  '145:urandom\n',
#  '146:utime\n',
#  '147:waitpid\n',
#  '148:walk\n',
#  '149:write\n']

# %%
file_lines = []
with open (full_file_name, 'r') as fin:
    for line in fin:
        file_lines.append(line.strip())  

file_lines
# Out:
# ['0:DirEntry',
#  '1:F_OK',
#  '2:MutableMapping',
#  '3:O_APPEND',
#  '4:O_BINARY',
#  '5:O_CREAT',
#  '6:O_EXCL',
#  '7:O_NOINHERIT',
#  '8:O_RANDOM',
#  '9:O_RDONLY',
#  '10:O_RDWR',
#  '11:O_SEQUENTIAL',
#  '12:O_SHORT_LIVED',
#  '13:O_TEMPORARY',
#  '14:O_TEXT',
#  '15:O_TRUNC',
#  '16:O_WRONLY',
#  '17:P_DETACH',
#  '18:P_NOWAIT',
#  '19:P_NOWAITO',
#  '20:P_OVERLAY',
#  '21:P_WAIT',
#  '22:PathLike',
#  '23:R_OK',
#  '24:SEEK_CUR',
#  '25:SEEK_END',
#  '26:SEEK_SET',
#  '27:TMP_MAX',
#  '28:W_OK',
#  '29:X_OK',
#  '30:_Environ',
#  '31:__all__',
#  '32:__builtins__',
#  '33:__cached__',
#  '34:__doc__',
#  '35:__file__',
#  '36:__loader__',
#  '37:__name__',
#  '38:__package__',
#  '39:__spec__',
#  '40:_execvpe',
#  '41:_exists',
#  '42:_exit',
#  '43:_fspath',
#  '44:_get_exports_list',
#  '45:_putenv',
#  '46:_unsetenv',
#  '47:_wrap_close',
#  '48:abc',
#  '49:abort',
#  '50:access',
#  '51:altsep',
#  '52:chdir',
#  '53:chmod',
#  '54:close',
#  '55:closerange',
#  '56:cpu_count',
#  '57:curdir',
#  '58:defpath',
#  '59:device_encoding',
#  '60:devnull',
#  '61:dup',
#  '62:dup2',
#  '63:environ',
#  '64:error',
#  '65:execl',
#  '66:execle',
#  '67:execlp',
#  '68:execlpe',
#  '69:execv',
#  '70:execve',
#  '71:execvp',
#  '72:execvpe',
#  '73:extsep',
#  '74:fdopen',
#  '75:fsdecode',
#  '76:fsencode',
#  '77:fspath',
#  '78:fstat',
#  '79:fsync',
#  '80:ftruncate',
#  '81:get_exec_path',
#  '82:get_handle_inheritable',
#  '83:get_inheritable',
#  '84:get_terminal_size',
#  '85:getcwd',
#  '86:getcwdb',
#  '87:getenv',
#  '88:getlogin',
#  '89:getpid',
#  '90:getppid',
#  '91:isatty',
#  '92:kill',
#  '93:linesep',
#  '94:link',
#  '95:listdir',
#  '96:lseek',
#  '97:lstat',
#  '98:makedirs',
#  '99:mkdir',
#  '100:name',
#  '101:open',
#  '102:pardir',
#  '103:path',
#  '104:pathsep',
#  '105:pipe',
#  '106:popen',
#  '107:putenv',
#  '108:read',
#  '109:readlink',
#  '110:remove',
#  '111:removedirs',
#  '112:rename',
#  '113:renames',
#  '114:replace',
#  '115:rmdir',
#  '116:scandir',
#  '117:sep',
#  '118:set_handle_inheritable',
#  '119:set_inheritable',
#  '120:spawnl',
#  '121:spawnle',
#  '122:spawnv',
#  '123:spawnve',
#  '124:st',
#  '125:startfile',
#  '126:stat',
#  '127:stat_result',
#  '128:statvfs_result',
#  '129:strerror',
#  '130:supports_bytes_environ',
#  '131:supports_dir_fd',
#  '132:supports_effective_ids',
#  '133:supports_fd',
#  '134:supports_follow_symlinks',
#  '135:symlink',
#  '136:sys',
#  '137:system',
#  '138:terminal_size',
#  '139:times',
#  '140:times_result',
#  '141:truncate',
#  '142:umask',
#  '143:uname_result',
#  '144:unlink',
#  '145:urandom',
#  '146:utime',
#  '147:waitpid',
#  '148:walk',
#  '149:write']

# %%
os_dir_from_file = [e.split(':')[1] for e in file_lines]

# %%
os_dir_from_file == dir(os)
# Out:
# True

# %%
os_dir_from_file = [e.split(':')[0] for e in file_lines]

# %%
os.rmdir (lab_dir)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-89cf27ffb5b2> in <module>
# ----> 1 os.rmdir (lab_dir)
#
# OSError: [WinError 145] The directory is not empty: './lab_dir'

# %%
import shutil
shutil.rmtree (lab_dir)
