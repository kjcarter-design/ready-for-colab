# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#This-counts-the-number-of-earthquakes" data-toc-modified-id="This-counts-the-number-of-earthquakes-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>This counts the number of earthquakes</a></span></li><li><span><a href="#This-list-the-specific-earthquakes" data-toc-modified-id="This-list-the-specific-earthquakes-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>This list the specific earthquakes</a></span></li></ul></div>

# %%
# conda install sodapy
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - sodapy
#
# Current channels:
#
#   - https://repo.anaconda.com/pkgs/main/osx-64
#   - https://repo.anaconda.com/pkgs/main/noarch
#   - https://repo.anaconda.com/pkgs/r/osx-64
#   - https://repo.anaconda.com/pkgs/r/noarch
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from sodapy import Socrata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/0q/ntwcxlqn1111n9nhc76xwp1w0000gn/T/ipykernel_13015/2559289117.py in <module>
#       1 import requests
#       2 import pandas as pd
# ----> 3 from sodapy import Socrata
#
# ModuleNotFoundError: No module named 'sodapy'

# %% [markdown]
# # This counts the number of earthquakes

# %%
r4 = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/count?starttime=2014-01-01&endtime=2015-01-01&minmagnitude=5")
r4.text
# Out:
# '1736'

# %% [markdown]
# # This list the specific earthquakes

# %%
r5 = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/query?format=text&starttime=2014-01-01&endtime=2014-01-02&minmagnitude=5")
r5.text
# Out:
# '#EventID|Time|Latitude|Longitude|Depth/km|Author|Catalog|Contributor|ContributorID|MagType|Magnitude|MagAuthor|EventLocationName\nusc000lvb5|2014-01-01T16:03:29.000|-13.8633|167.249|187|us|us|us|usc000lvb5|mww|6.5|us|32 km W of Sola, Vanuatu\nusc000lv5e|2014-01-01T00:01:16.610|19.0868|120.2389|10.07|us|us|us|usc000lv5e|mb|5.1|us|76 km NNW of Davila, Philippines\n'

# %%
# vaccination distribution
r7 = requests.get("https://data.cdc.gov/resource/saz5-9hgg.json")
r7.text
# Out:
# '[{"jurisdiction":"Connecticut","week_of_allocations":"2021-06-21T00:00:00.000","_1st_dose_allocations":"54360","_2nd_dose_allocations":"54360"}\n,{"jurisdiction":"Maine","week_of_allocations":"2021-06-21T00:00:00.000","_1st_dose_allocations":"21420","_2nd_dose_allocations":"21420"}\n,{"jurisdiction":"Massachusetts","week_of_allocations":"2021-06-21T00:00:00.000","_1st_dose_allocations":"104580","_2nd_dose_allocations":"104580"}\n,{"jurisdiction":"New Hampshire","week_of_allocations":"2021-06-21T00:00:00.000","_1st_dose_allocations":"21420","_2nd_dose_allocations":"21420"}\n,{"jurisdiction":"Rhode Island","week_of_allocations":"2021-06-21T00:00:00.000","_1st_dose_allocations":"17280","_2nd_dose_allocations":"17280"}\n,{"jurisdiction":"Vermont","week_of_allocations":"2021-06-21T00:00:00.000","_1st_dose_allocations":"11070","_2nd_dose_allocations":"11070"}\n,{"jurisdiction":"New Jersey","week_of_allocations":"2021-06-21T00:00:00.000","_1st_dose_allocations":"132210","_2nd_dose_allocati
# ...

# %%
r8 = requests.get("https://data.cdc.gov/resource/saz5-9hgg.json?jurisdiction=Vermont")
r8.text
# Out:
# '[{"jurisdiction":"Vermont","week_of_allocations":"2021-06-21T00:00:00.000","_1st_dose_allocations":"11070","_2nd_dose_allocations":"11070"}\n,{"jurisdiction":"Vermont","week_of_allocations":"2021-06-14T00:00:00.000","_1st_dose_allocations":"11070","_2nd_dose_allocations":"11070"}\n,{"jurisdiction":"Vermont","week_of_allocations":"2021-06-07T00:00:00.000","_1st_dose_allocations":"11070","_2nd_dose_allocations":"11070"}\n,{"jurisdiction":"Vermont","week_of_allocations":"2021-05-31T00:00:00.000","_1st_dose_allocations":"11070","_2nd_dose_allocations":"11070"}\n,{"jurisdiction":"Vermont","week_of_allocations":"2021-05-24T00:00:00.000","_1st_dose_allocations":"10530","_2nd_dose_allocations":"10530"}\n,{"jurisdiction":"Vermont","week_of_allocations":"2021-05-17T00:00:00.000","_1st_dose_allocations":"10530","_2nd_dose_allocations":"10530"}\n,{"jurisdiction":"Vermont","week_of_allocations":"2021-05-10T00:00:00.000","_1st_dose_allocations":"10530","_2nd_dose_allocations":"10530"}\n,{"jurisdi
# ...

# %%
results_df = pd.DataFrame(r8)

# %%
client = Socrata("data.cdc.gov", None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0q/ntwcxlqn1111n9nhc76xwp1w0000gn/T/ipykernel_13015/3751343928.py in <module>
# ----> 1 client = Socrata("data.cdc.gov", None)
#
# NameError: name 'Socrata' is not defined

# %%
results = client.get("saz5-9hgg", limit=2000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0q/ntwcxlqn1111n9nhc76xwp1w0000gn/T/ipykernel_13015/2841441259.py in <module>
# ----> 1 results = client.get("saz5-9hgg", limit=2000)
#
# NameError: name 'client' is not defined

# %%
results = client.get("saz5-9hgg", limit=2000)

# %%
results_df = pd.DataFrame.from_records(results)

# %%
results_df.head()

# %%
url = ("https://data.cdc.gov/resource/saz5-9hgg.json?jurisdiction=Massachusetts")

# %%
r10 = pd.read_csv(url)
r10.shape

# %%
r10.head()

# %%
r20 = ('https://data.cdc.gov/resource/vbim-akqf.json?current_status=Laboratory-confirmed case')

# %%
big = pd.read_csv(r20)

# %%
client = Socrata("data.cdc.gov", 'omyrUm8mb26Hn4jHZelVooiBg7bvJDpoWZgkP7rw')

# %%
results = client.get("vbim")

# %%
results_df = pd.DataFrame.from_records(results)

# %%
results_df.shape
